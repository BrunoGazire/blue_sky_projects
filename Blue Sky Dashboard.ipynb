# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("BasicAllSeason_Summer_Commercial_Drive.csv")

# %%
df = pd.DataFrame(data)

# %%
df = df.rename(columns={"Seasom" : "Season"})

# %%
df.columns
# Out:
# Index(['Vendor', 'Product', 'Variant', 'SKU', 'Product Type', 'Price',
#        'Full price', 'Retail Value', 'Stock', 'Sales', 'Sales (gross)',
#        'Refunds', 'Season', 'Location'],
#       dtype='object')

# %%
data = pd.read_csv("BasicsAllSeason_Spring_Commercial_Drive.csv")

# %%
df1 = pd.DataFrame(data)

# %%
df1.columns
# Out:
# Index(['Vendor', 'Product', 'Variant', 'SKU', 'Product Type', 'Price',
#        'Full price', 'Retail Value', 'Stock', 'Sales', 'Sales (gross)',
#        'Refunds', 'Season', 'Location'],
#       dtype='object')

# %%
df1
# Out:
#                 Vendor                              Product Variant       SKU  \
# 0     Basic All Season         Riley Legging, Black, Bamboo   SMALL   8616292
# 1     Basic All Season            Ruby Capri, Black, Bamboo      1X    159996
# 2     Basic All Season         Riley Legging, Black, Bamboo  MEDIUM   8616293
# 3     Basic All Season  Riley Legging Petite, Black, Bamboo  MEDIUM   8116293
# 4     Basic All Season           Reanna Tank, Black, Bamboo   LARGE   4711194
# ...                ...                                  ...     ...       ...
# 1373  Basic All Season          Relaxed Tank, White, Bamboo      3X   4091008
# 1374  Basic All Season              Mia Top, Coffee, Bamboo   SMALL  47940332
# 1375  Basic All Season       Relaxed Tank, Charcoal, Bamboo      1X  40910476
# 1376  Basic All Season               Kim Cap, White, Bamboo      2X   4755107
# 1377  Basic All Season            Jazz Tank, Indigo, Bamboo  MEDIUM   4530223
#
# ...

# %%
df
# Out:
#                 Vendor                       Product Variant       SKU  \
# 0     Basic All Season     Ruby Capri, Black, Bamboo   LARGE    159994
# 1     Basic All Season     Ruby Capri, Black, Bamboo  MEDIUM    159993
# 2     Basic All Season     Ruby Capri, Black, Bamboo      1X    159996
# 3     Basic All Season  Riley Legging, Black, Bamboo   LARGE   8616294
# 4     Basic All Season     Nadine Pant, Khaki, Modal   LARGE  87264614
# ...                ...                           ...     ...       ...
# 1373  Basic All Season   Relaxed Tank, White, Bamboo      3X   4091008
# 1374  Basic All Season       Mia Top, Coffee, Bamboo   SMALL  47940332
# 1375  Basic All Season        Kim Cap, White, Bamboo      2X   4755107
# 1376  Basic All Season     Nadia Pant, Indigo, Modal  XSMALL  84064221
# 1377  Basic All Season     Jazz Tank, Indigo, Bamboo  MEDIUM   4530223
#
#          Product Type  Price  Full price Retail Value  Stock  Sales  \
# ...

# %%
masterdf = pd.concat([df, df1])

# %%
masterdf
# Out:
#                 Vendor                         Product Variant       SKU  \
# 0     Basic All Season       Ruby Capri, Black, Bamboo   LARGE    159994
# 1     Basic All Season       Ruby Capri, Black, Bamboo  MEDIUM    159993
# 2     Basic All Season       Ruby Capri, Black, Bamboo      1X    159996
# 3     Basic All Season    Riley Legging, Black, Bamboo   LARGE   8616294
# 4     Basic All Season       Nadine Pant, Khaki, Modal   LARGE  87264614
# ...                ...                             ...     ...       ...
# 1373  Basic All Season     Relaxed Tank, White, Bamboo      3X   4091008
# 1374  Basic All Season         Mia Top, Coffee, Bamboo   SMALL  47940332
# 1375  Basic All Season  Relaxed Tank, Charcoal, Bamboo      1X  40910476
# 1376  Basic All Season          Kim Cap, White, Bamboo      2X   4755107
# 1377  Basic All Season       Jazz Tank, Indigo, Bamboo  MEDIUM   4530223
#
#          Product Type  Price  Full price Retail Value  Stock  Sales  \
# ...

# %%
df
# Out:
#                 Vendor                       Product Variant       SKU  \
# 0     Basic All Season     Ruby Capri, Black, Bamboo   LARGE    159994
# 1     Basic All Season     Ruby Capri, Black, Bamboo  MEDIUM    159993
# 2     Basic All Season     Ruby Capri, Black, Bamboo      1X    159996
# 3     Basic All Season  Riley Legging, Black, Bamboo   LARGE   8616294
# 4     Basic All Season     Nadine Pant, Khaki, Modal   LARGE  87264614
# ...                ...                           ...     ...       ...
# 1373  Basic All Season   Relaxed Tank, White, Bamboo      3X   4091008
# 1374  Basic All Season       Mia Top, Coffee, Bamboo   SMALL  47940332
# 1375  Basic All Season        Kim Cap, White, Bamboo      2X   4755107
# 1376  Basic All Season     Nadia Pant, Indigo, Modal  XSMALL  84064221
# 1377  Basic All Season     Jazz Tank, Indigo, Bamboo  MEDIUM   4530223
#
#          Product Type  Price  Full price Retail Value  Stock  Sales  \
# ...

# %%
df
# Out:
#                 Vendor                       Product Variant       SKU  \
# 0     Basic All Season     Ruby Capri, Black, Bamboo   LARGE    159994
# 1     Basic All Season     Ruby Capri, Black, Bamboo  MEDIUM    159993
# 2     Basic All Season     Ruby Capri, Black, Bamboo      1X    159996
# 3     Basic All Season  Riley Legging, Black, Bamboo   LARGE   8616294
# 4     Basic All Season     Nadine Pant, Khaki, Modal   LARGE  87264614
# ...                ...                           ...     ...       ...
# 1373  Basic All Season   Relaxed Tank, White, Bamboo      3X   4091008
# 1374  Basic All Season       Mia Top, Coffee, Bamboo   SMALL  47940332
# 1375  Basic All Season        Kim Cap, White, Bamboo      2X   4755107
# 1376  Basic All Season     Nadia Pant, Indigo, Modal  XSMALL  84064221
# 1377  Basic All Season     Jazz Tank, Indigo, Bamboo  MEDIUM   4530223
#
#          Product Type  Price  Full price Retail Value  Stock  Sales  \
# ...

# %%
data = pd.read_csv("BasicSS_Spring_Commercial_Drive.csv")

# %%
df3 = pd.DataFrame(data)

# %%
data = pd.read_csv("BasicSS_Summer_Commercial_Drive.csv")

# %%
df4 = pd.DataFrame(data)

# %%
data = pd.read_csv("Basics_AllSeason_Spring_North_Vancouver.csv")

# %%
df5 = pd.DataFrame(data)

# %%
data = pd.read_csv("Basics_AllSeason_Summer_North_Vancouver.csv")

# %%
df6 = pd.DataFrame(data)

# %%
data = pd.read_csv("BasicSS_Spring_North_Vancouver.csv")

# %%
df7 = pd.DataFrame(data)

# %%
data = pd.read_csv("BasicSS_Summer_North_Vancouver.csv")

# %%
df8 = pd.DataFrame(data)

# %%
data = pd.read_csv("BasicsAllSeason_Spring_Kitsilano.csv")

# %%
df9 = pd.DataFrame(data)

# %%
data = pd.read_csv("BasicsAllSeason_Summer_Kitsilano.csv")

# %%
df10 = pd.DataFrame(data)

# %%
data = pd.read_csv("BasicSS_Spring_Kitsilano.csv")

# %%
df11 = pd.DataFrame(data)

# %%
data = pd.read_csv("BasicSS_Summer_Kitsilano.csv")

# %%
df12 = pd.DataFrame(data)

# %%
master_df = pd.concat([df, df1, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])

# %%
master_df.columns
# Out:
# Index(['Vendor', 'Product', 'Variant', 'SKU', 'Product Type', 'Price',
#        'Full price', 'Retail Value', 'Stock', 'Sales', 'Sales (gross)',
#        'Refunds', 'Season', 'Location'],
#       dtype='object')

# %%
master_filter = master_df[["Vendor", "Product", "Variant", "Product Type", "Retail Value", "Stock", "Sales", "Refunds", "Season", "Location"]]

# %%
master_filter
# Out:
#                Vendor                       Product Variant  \
# 0    Basic All Season     Ruby Capri, Black, Bamboo   LARGE
# 1    Basic All Season     Ruby Capri, Black, Bamboo  MEDIUM
# 2    Basic All Season     Ruby Capri, Black, Bamboo      1X
# 3    Basic All Season  Riley Legging, Black, Bamboo   LARGE
# 4    Basic All Season     Nadine Pant, Khaki, Modal   LARGE
# ..                ...                           ...     ...
# 840          Basic SS  Kathy Jacket, Coffee, Bamboo  XSMALL
# 841          Basic SS   Gaylene Capri, Teal, Bamboo  MEDIUM
# 842          Basic SS  Margorie Top, Royale, Bamboo  MEDIUM
# 843          Basic SS   Magna Skort, Royale, Bamboo  XSMALL
# 844          Basic SS    Liane Dress, Black, Bamboo      1X
#
#              Product Type Retail Value  Stock  Sales  Refunds   Season  \
# 0         Women - Legging    10,608.00    272     11        0  Summer
# 1         Women - Legging     9,633.00    247      6        0  Summer
# ...

# %%
master_filter.to_csv("Local_Stores.csv")
